# %% [markdown]
# <a href="https://colab.research.google.com/github/alizadangi02/Python/blob/main/data_manipulation.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

sessions_df = pd.read_csv("/content/charging_sessions.csv")
sessions_df
# Out:
#        session_id customer_id  station_id   session_start_time  kwh_charged  \
# 0          S00001       C3806          18  2025-10-04 05:42:00    46.691971
# 1          S00002       C4931          98  2025-10-19 16:12:00    39.061716
# 2          S00003       C2250         145  2025-09-14 15:18:00    30.280525
# 3          S00004       C3790         165  2025-10-06 23:22:00    44.577079
# 4          S00005       C4834          68  2025-09-26 09:07:00    37.998209
# ...           ...         ...         ...                  ...          ...
# 113995    S113996       C7127          70  2025-10-24 11:32:00    33.221606
# 113996    S113997       C1406         131  2025-09-04 00:41:00    55.850678
# 113997    S113998       C2269          14  2025-10-29 14:11:00    44.547895
# 113998    S113999       C5246         155  2025-10-22 10:19:00    30.946160
# 113999    S114000       C3351          61  2025-09-22 21:36:00    42.229782
#
#         cost_per_kwh  total_cost
# ...

# %%
sessions_df.head(10)
# Out:
#   session_id customer_id  station_id   session_start_time  kwh_charged  \
# 0     S00001       C3806          18  2025-10-04 05:42:00    46.691971
# 1     S00002       C4931          98  2025-10-19 16:12:00    39.061716
# 2     S00003       C2250         145  2025-09-14 15:18:00    30.280525
# 3     S00004       C3790         165  2025-10-06 23:22:00    44.577079
# 4     S00005       C4834          68  2025-09-26 09:07:00    37.998209
# 5     S00006       C6834          55  2025-09-01 16:53:00    42.520575
# 6     S00007       C0967         131  2025-11-02 12:01:00    47.133534
# 7     S00008       C5713          33  2025-10-30 12:14:00    20.677966
# 8     S00009       C5256          85  2025-09-21 08:58:00    26.960971
# 9     S00010       C7412          92  2025-11-05 14:04:00    67.213731
#
#    cost_per_kwh  total_cost
# 0      1.851397   86.445363
# 1      3.256199  127.192717
# 2      2.704520   81.894289
# 3      1.851397   82.529859
# 4      2.704520  102.766920
# ...

# %%
sessions_df.tail()
# Out:
#        session_id customer_id  station_id   session_start_time  kwh_charged  \
# 113995    S113996       C7127          70  2025-10-24 11:32:00    33.221606
# 113996    S113997       C1406         131  2025-09-04 00:41:00    55.850678
# 113997    S113998       C2269          14  2025-10-29 14:11:00    44.547895
# 113998    S113999       C5246         155  2025-10-22 10:19:00    30.946160
# 113999    S114000       C3351          61  2025-09-22 21:36:00    42.229782
#
#         cost_per_kwh  total_cost
# 113995      2.704520   89.848502
# 113996      1.851397  103.401763
# 113997      2.704520  120.480680
# 113998      2.704520   83.694513
# 113999      1.851397   78.184081

# %%
sessions_df.shape
# Out:
# (114000, 7)

# %%
sessions_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 114000 entries, 0 to 113999
# Data columns (total 7 columns):
#  #   Column              Non-Null Count   Dtype
# ---  ------              --------------   -----
#  0   session_id          114000 non-null  object
#  1   customer_id         114000 non-null  object
#  2   station_id          114000 non-null  int64
#  3   session_start_time  114000 non-null  object
#  4   kwh_charged         114000 non-null  float64
#  5   cost_per_kwh        114000 non-null  float64
#  6   total_cost          114000 non-null  float64
# dtypes: float64(3), int64(1), object(3)
# memory usage: 6.1+ MB

# %%
sessions_df.describe()
# Out:
#           station_id    kwh_charged   cost_per_kwh     total_cost
# count  114000.000000  114000.000000  114000.000000  114000.000000
# mean       97.856447      39.125132       2.561615     100.210541
# std        48.767888      12.729146       0.506239      38.634723
# min         1.000000      13.401015       1.851397      24.810596
# 25%        62.000000      30.078538       1.851397      71.845002
# 50%       100.000000      37.934537       2.704520      95.703010
# 75%       141.000000      48.065057       2.704520     124.789060
# max       182.000000      75.995841       3.256199     247.130372
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_0['station_id'].plot(kind='hist', bins=20, title='station_id')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# ...
